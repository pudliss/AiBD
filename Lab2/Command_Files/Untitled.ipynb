# %%
import pandas as pd
my_cols = [str(i+1) for i in range(31)]
df = pd.read_csv("../Original_Data/weather.txt", sep=' I |  I-|I  |  -', engine='python',names=my_cols)
df=df[60:96]
for i in range(12):
    df.drop(62+3*i, axis=0, inplace=True)

# %%
display(df)
# Out:
#                               1      2      3      4      5      6      7  \
# 60  MX000017004195701TMAX  260    250    240    270    260    280    290
# 61  MX000017004195701TMIN  120    110    120    140    140    130    130
# 63  MX000017004195702TMAX  270    280    280    280    280    280    280
# 64  MX000017004195702TMIN  140    140    150    150    150    140    120
# 66  MX000017004195703TMAX  280    280    280    280    280    280    290
# 67  MX000017004195703TMIN  130    130    140    120    120    120    110
# 69  MX000017004195704TMAX  300    290    290    310    320    300    320
# 70  MX000017004195704TMIN  160    160    150    140    150    150    170
# 72  MX000017004195705TMAX  310    310    310    310    290    290    240
# 73  MX000017004195705TMIN  170    170    180    180    170    140    140
# 75  MX000017004195706TMAX  290    280    290    280    260    290    290
# 76  MX000017004195706TMIN  180    170    170    170    160    170    180
# ...
